# %%
import pandas as pd

# %%
df = pd.read_csv('spotify.csv')

# %%
df
# Out:
#      Unnamed: 0    Age  Gender spotify_usage_period  \
# 0             0  20-35  Female    More than 2 years
# 1             1  12-20    Male    More than 2 years
# 2             2  35-60  Others   6 months to 1 year
# 3             3  20-35  Female    1 year to 2 years
# 4             4  20-35  Female    1 year to 2 years
# ..          ...    ...     ...                  ...
# 515         515  20-35  Female    More than 2 years
# 516         516  20-35  Female    More than 2 years
# 517         517  20-35  Female    More than 2 years
# 518         518  20-35  Female   6 months to 1 year
# 519         519  20-35  Female    More than 2 years
#
#                              spotify_listening_device  \
# 0                  Smart speakers or voice assistants
# 1                                  Computer or laptop
# 2                  Smart speakers or voice assistants
# 3      Smartphone, Smart speakers or voice assistants
# 4                                          Smartphone
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 520 entries, 0 to 519
# Data columns (total 21 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Unnamed: 0                   520 non-null    int64
#  1   Age                          520 non-null    object
#  2   Gender                       520 non-null    object
#  3   spotify_usage_period         520 non-null    object
#  4   spotify_listening_device     520 non-null    object
#  5   spotify_subscription_plan    520 non-null    object
#  6   premium_sub_willingness      520 non-null    object
#  7   preffered_premium_plan       312 non-null    object
#  8   preferred_listening_content  520 non-null    object
#  9   fav_music_genre              520 non-null    object
#  10  music_time_slot              520 non-null    object
#  11  music_Influencial_mood       520 non-null    object
#  12  music_lis_frequency          520 non-null    object
# ...

# %%
df.ndim
# Out:
# 2

# %%
df.shape
# Out:
# (520, 21)

# %%
df.size
# Out:
# 10920

# %%
df.index
# Out:
# RangeIndex(start=0, stop=520, step=1)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Age', 'Gender', 'spotify_usage_period',
#        'spotify_listening_device', 'spotify_subscription_plan',
#        'premium_sub_willingness', 'preffered_premium_plan',
#        'preferred_listening_content', 'fav_music_genre', 'music_time_slot',
#        'music_Influencial_mood', 'music_lis_frequency', 'music_expl_method',
#        'music_recc_rating', 'pod_lis_frequency', 'fav_pod_genre',
#        'preffered_pod_format', 'pod_host_preference', 'preffered_pod_duration',
#        'pod_variety_satisfaction'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Unnamed: 0                      int64
# Age                            object
# Gender                         object
# spotify_usage_period           object
# spotify_listening_device       object
# spotify_subscription_plan      object
# premium_sub_willingness        object
# preffered_premium_plan         object
# preferred_listening_content    object
# fav_music_genre                object
# music_time_slot                object
# music_Influencial_mood         object
# music_lis_frequency            object
# music_expl_method              object
# music_recc_rating               int64
# pod_lis_frequency              object
# fav_pod_genre                  object
# preffered_pod_format           object
# pod_host_preference            object
# preffered_pod_duration         object
# pod_variety_satisfaction       object
# dtype: object

# %%
df.values
# Out:
# array([[0, '20-35', 'Female', ..., 'Both', 'Both', 'Ok'],
#        [1, '12-20', 'Male', ..., 'Both', nan, 'Satisfied'],
#        [2, '35-60', 'Others', ..., nan, 'Both', 'Satisfied'],
#        ...,
#        [517, '20-35', 'Female', ..., 'Both', 'Shorter', 'Ok'],
#        [518, '20-35', 'Female', ..., 'Both', 'Longer', 'Satisfied'],
#        [519, '20-35', 'Female', ..., nan, nan, 'Ok']], dtype=object)

# %%
df.select_dtypes('int64')
# Out:
#      Unnamed: 0  music_recc_rating
# 0             0                  3
# 1             1                  2
# 2             2                  4
# 3             3                  4
# 4             4                  4
# ..          ...                ...
# 515         515                  5
# 516         516                  2
# 517         517                  3
# 518         518                  2
# 519         519                  3
#
# [520 rows x 2 columns]

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=520, step=1),
#  Index(['Unnamed: 0', 'Age', 'Gender', 'spotify_usage_period',
#         'spotify_listening_device', 'spotify_subscription_plan',
#         'premium_sub_willingness', 'preffered_premium_plan',
#         'preferred_listening_content', 'fav_music_genre', 'music_time_slot',
#         'music_Influencial_mood', 'music_lis_frequency', 'music_expl_method',
#         'music_recc_rating', 'pod_lis_frequency', 'fav_pod_genre',
#         'preffered_pod_format', 'pod_host_preference', 'preffered_pod_duration',
#         'pod_variety_satisfaction'],
#        dtype='object')]

# %%
df.memory_usage
# Out:
# <bound method DataFrame.memory_usage of      Unnamed: 0    Age  Gender spotify_usage_period  \
# 0             0  20-35  Female    More than 2 years
# 1             1  12-20    Male    More than 2 years
# 2             2  35-60  Others   6 months to 1 year
# 3             3  20-35  Female    1 year to 2 years
# 4             4  20-35  Female    1 year to 2 years
# ..          ...    ...     ...                  ...
# 515         515  20-35  Female    More than 2 years
# 516         516  20-35  Female    More than 2 years
# 517         517  20-35  Female    More than 2 years
# 518         518  20-35  Female   6 months to 1 year
# 519         519  20-35  Female    More than 2 years
#
#                              spotify_listening_device  \
# 0                  Smart speakers or voice assistants
# 1                                  Computer or laptop
# 2                  Smart speakers or voice assistants
# 3      Smartphone, Smart speakers or voice assistants
# ...

# %%
df.empty
# Out:
# False

# %%
df.head(n=25)
# Out:
#     Unnamed: 0    Age  Gender spotify_usage_period  \
# 0            0  20-35  Female    More than 2 years
# 1            1  12-20    Male    More than 2 years
# 2            2  35-60  Others   6 months to 1 year
# 3            3  20-35  Female    1 year to 2 years
# 4            4  20-35  Female    1 year to 2 years
# 5            5  20-35    Male    More than 2 years
# 6            6  20-35  Female    1 year to 2 years
# 7            7  20-35  Female   Less than 6 months
# 8            8  20-35  Female   Less than 6 months
# 9            9  20-35  Female    More than 2 years
# 10          10  20-35  Female    More than 2 years
# 11          11  20-35  Female    1 year to 2 years
# 12          12  20-35  Female    1 year to 2 years
# 13          13  20-35  Female    More than 2 years
# 14          14  20-35  Female    More than 2 years
# 15          15  20-35  Female    More than 2 years
# 16          16  20-35  Female   Less than 6 months
# ...

# %%
df.tail()
# Out:
#      Unnamed: 0    Age  Gender spotify_usage_period  \
# 515         515  20-35  Female    More than 2 years
# 516         516  20-35  Female    More than 2 years
# 517         517  20-35  Female    More than 2 years
# 518         518  20-35  Female   6 months to 1 year
# 519         519  20-35  Female    More than 2 years
#
#                              spotify_listening_device  \
# 515  Smartphone, Computer or laptop, Wearable devices
# 516                    Smartphone, Computer or laptop
# 517                                        Smartphone
# 518                                        Smartphone
# 519                    Smartphone, Computer or laptop
#
#        spotify_subscription_plan premium_sub_willingness  \
# 515          Free (ad-supported)                     Yes
# 516          Free (ad-supported)                     Yes
# 517          Free (ad-supported)                      No
# 518  Premium (paid subscription)                     Yes
# ...

# %%
df.Age
# Out:
# 0      20-35
# 1      12-20
# 2      35-60
# 3      20-35
# 4      20-35
#        ...
# 515    20-35
# 516    20-35
# 517    20-35
# 518    20-35
# 519    20-35
# Name: Age, Length: 520, dtype: object

# %%
df[['Age']]
# Out:
#        Age
# 0    20-35
# 1    12-20
# 2    35-60
# 3    20-35
# 4    20-35
# ..     ...
# 515  20-35
# 516  20-35
# 517  20-35
# 518  20-35
# 519  20-35
#
# [520 rows x 1 columns]

# %%
data = {'col1': [1, 2], 'col2': [3, 4]}

# %%
data
# Out:
# {'col1': [1, 2], 'col2': [3, 4]}

# %%
data = pd.DataFrame(data)

# %%
data
# Out:
#    col1  col2
# 0     1     3
# 1     2     4

# %%
data['col1'] = [4, 8]
data['col2'] = [2, 9]

# %%
data
# Out:
#    col1  col2
# 0     4     2
# 1     8     9

# %%
data['col1'] = '5'

# %%
data['col2'] = '6'

# %%
data
# Out:
#   col1 col2
# 0    5    6
# 1    5    6

# %%
data['col1'] = [5, 'hello']

# %%
data
# Out:
#     col1 col2
# 0      5    6
# 1  hello    6

# %%
data.dtypes
# Out:
# col1    object
# col2    object
# dtype: object

# %%
data['col3'] = [7, 8]

# %%
data
# Out:
#     col1 col2  col3
# 0      5    6     7
# 1  hello    6     8

# %%
dataset = pd.read_csv('titanic.csv')

# %%
dataset
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
dataset['Fare'].mean()
# Out:
# 32.204207968574636

# %%
dataset['Fare'].max()
# Out:
# 512.3292

# %%
dataset.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
dataset.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
dataset
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
dataset.iloc[[0, 4]]
# Out:
#    PassengerId  Survived  Pclass                      Name   Sex   Age  SibSp  \
# 0            1         0       3   Braund, Mr. Owen Harris  male  22.0      1
# 4            5         0       3  Allen, Mr. William Henry  male  35.0      0
#
#    Parch     Ticket  Fare Cabin Embarked
# 0      0  A/5 21171  7.25   NaN        S
# 4      0     373450  8.05   NaN        S

# %%
dataset.head(4)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S

# %%
dataset.drop(['Pclass'], axis=1, inplace=True)

# %%
dataset
# Out:
#      PassengerId  Survived                                               Name  \
# 0              1         0                            Braund, Mr. Owen Harris
# 1              2         1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3         1                             Heikkinen, Miss. Laina
# 3              4         1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              5         0                           Allen, Mr. William Henry
# ..           ...       ...                                                ...
# 886          887         0                              Montvila, Rev. Juozas
# 887          888         1                       Graham, Miss. Margaret Edith
# 888          889         0           Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1                              Behr, Mr. Karl Howell
# 890          891         0                                Dooley, Mr. Patrick
#
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Name         891 non-null    object
#  3   Sex          891 non-null    object
#  4   Age          714 non-null    float64
#  5   SibSp        891 non-null    int64
#  6   Parch        891 non-null    int64
#  7   Ticket       891 non-null    object
#  8   Fare         891 non-null    float64
#  9   Cabin        204 non-null    object
#  10  Embarked     889 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 76.7+ KB

# %%
dataset['Age'].agg(['sum', 'mean'])
# Out:
# sum     21205.170000
# mean       29.699118
# Name: Age, dtype: float64

# %%
dataset['Age'].product()
# Out:
# C:\Users\utsab\anaconda3\Lib\site-packages\numpy\core\_methods.py:53: RuntimeWarning: overflow encountered in reduce
#   return umr_prod(a, axis, dtype, out, keepdims, initial, where)
# inf

# %%
dataset['Age'].isna()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888     True
# 889    False
# 890    False
# Name: Age, Length: 891, dtype: bool

# %%
df = pd.read_csv('titanic.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
def change_survided(val):
    if val == 1:
        return True
    else: 
        return False

# %%
df['Survived'] = df['Survived'].apply(lambda val: True if val == 1 else False)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1     False       3
# 1            2      True       1
# 2            3      True       3
# 3            4      True       1
# 4            5     False       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df['SibSp'].unique()
# Out:
# array([1, 0, 3, 4, 2, 5, 8], dtype=int64)

# %%
df['Parch'].unique()
# Out:
# array([0, 1, 2, 5, 3, 4, 6], dtype=int64)

# %%
def update_passenger_id(id):
    return 'p' + str(id)

# %%
df['PassengerId'] = df['PassengerId'].apply(lambda id: 'p' + str(id))

# %%
df.head()
# Out:
#   PassengerId  Survived  Pclass  \
# 0          p1     False       3
# 1          p2      True       1
# 2          p3      True       3
# 3          p4      True       1
# 4          p5     False       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df = pd.read_csv('Bengaluru_House_Data.csv')

# %%
df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
df.isna().sum()
# Out:
# area_type          0
# availability       0
# location           1
# size              16
# society         5502
# total_sqft         0
# bath              73
# balcony          609
# price              0
# dtype: int64

# %%
5502/13320*100
# Out:
# 41.306306306306304

# %%
df['bath'].unique()
# Out:
# array([ 2.,  5.,  3.,  4.,  6.,  1.,  9., nan,  8.,  7., 11., 10., 14.,
#        27., 12., 16., 40., 15., 13., 18.])

# %%
df['bath'].idxmax()
# Out:
# 4684

# %%
df[df['bath'] == 40.0]
# Out:
#        area_type   availability     location        size society total_sqft  \
# 4684  Plot  Area  Ready To Move  Munnekollal  43 Bedroom     NaN       2400
#
#       bath  balcony  price
# 4684  40.0      0.0  660.0
