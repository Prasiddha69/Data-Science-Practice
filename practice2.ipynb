# %%
import numpy as np
import pandas as pd

# %%
df =pd.read_csv("collegePlace.csv")

# %%
df.head(5)
# Out:
#    Age  Gender                         Stream  Internships  CGPA  Hostel  \
# 0   22    Male  Electronics And Communication            1     8       1
# 1   21  Female               Computer Science            0     7       1
# 2   22  Female         Information Technology            1     6       0
# 3   21    Male         Information Technology            0     8       0
# 4   22    Male                     Mechanical            0     8       1
#
#    HistoryOfBacklogs  PlacedOrNot
# 0                  1            1
# 1                  1            1
# 2                  0            1
# 3                  1            1
# 4                  0            1

# %%
df.tail(5)
# Out:
#       Age Gender                  Stream  Internships  CGPA  Hostel  \
# 2961   23   Male  Information Technology            0     7       0
# 2962   23   Male              Mechanical            1     7       1
# 2963   22   Male  Information Technology            1     7       0
# 2964   22   Male        Computer Science            1     7       0
# 2965   23   Male                   Civil            0     8       0
#
#       HistoryOfBacklogs  PlacedOrNot
# 2961                  0            0
# 2962                  0            0
# 2963                  0            0
# 2964                  0            0
# 2965                  0            1

# %%
df["HistoryOfBacklogs"].max()
# Out:
# 1

# %%
# df.corr("Internships","CGPA")

# %%
df["CGPA"].unique()
# Out:
# array([8, 7, 6, 9, 5])

# %%
df.corr(numeric_only=True)
# Out:
#                         Age  Internships      CGPA    Hostel  \
# Age                1.000000     0.006552 -0.119787  0.003042
# Internships        0.006552     1.000000  0.023496  0.004617
# CGPA              -0.119787     0.023496  1.000000  0.014991
# Hostel             0.003042     0.004617  0.014991  1.000000
# HistoryOfBacklogs -0.042586    -0.015118  0.002576  0.103506
# PlacedOrNot        0.046943     0.179334  0.588648 -0.038182
#
#                    HistoryOfBacklogs  PlacedOrNot
# Age                        -0.042586     0.046943
# Internships                -0.015118     0.179334
# CGPA                        0.002576     0.588648
# Hostel                      0.103506    -0.038182
# HistoryOfBacklogs           1.000000    -0.022337
# PlacedOrNot                -0.022337     1.000000

# %%
df
# Out:
#       Age  Gender                         Stream  Internships  CGPA  Hostel  \
# 0      22    Male  Electronics And Communication            1     8       1
# 1      21  Female               Computer Science            0     7       1
# 2      22  Female         Information Technology            1     6       0
# 3      21    Male         Information Technology            0     8       0
# 4      22    Male                     Mechanical            0     8       1
# ...   ...     ...                            ...          ...   ...     ...
# 2961   23    Male         Information Technology            0     7       0
# 2962   23    Male                     Mechanical            1     7       1
# 2963   22    Male         Information Technology            1     7       0
# 2964   22    Male               Computer Science            1     7       0
# 2965   23    Male                          Civil            0     8       0
#
#       HistoryOfBacklogs  PlacedOrNot
# ...

# %%
df.dtypes
# Out:
# Age                   int64
# Gender               object
# Stream               object
# Internships           int64
# CGPA                  int64
# Hostel                int64
# HistoryOfBacklogs     int64
# PlacedOrNot           int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2966 entries, 0 to 2965
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Age                2966 non-null   int64
#  1   Gender             2966 non-null   object
#  2   Stream             2966 non-null   object
#  3   Internships        2966 non-null   int64
#  4   CGPA               2966 non-null   int64
#  5   Hostel             2966 non-null   int64
#  6   HistoryOfBacklogs  2966 non-null   int64
#  7   PlacedOrNot        2966 non-null   int64
# dtypes: int64(6), object(2)
# memory usage: 185.5+ KB

# %%
df.isna().sum()
# Out:
# Age                  0
# Gender               0
# Stream               0
# Internships          0
# CGPA                 0
# Hostel               0
# HistoryOfBacklogs    0
# PlacedOrNot          0
# dtype: int64

# %%
df["Age"].max()
# Out:
# 30

# %%
df.CGPA.max()
# Out:
# 9

# %%
df.Stream.unique()
# Out:
# array(['Electronics And Communication', 'Computer Science',
#        'Information Technology', 'Mechanical', 'Electrical', 'Civil'],
#       dtype=object)

# %%
df["Habit"]=None

# %%
df
# Out:
#       Age  Gender                         Stream  Internships  CGPA  Hostel  \
# 0      22    Male  Electronics And Communication            1     8       1
# 1      21  Female               Computer Science            0     7       1
# 2      22  Female         Information Technology            1     6       0
# 3      21    Male         Information Technology            0     8       0
# 4      22    Male                     Mechanical            0     8       1
# ...   ...     ...                            ...          ...   ...     ...
# 2961   23    Male         Information Technology            0     7       0
# 2962   23    Male                     Mechanical            1     7       1
# 2963   22    Male         Information Technology            1     7       0
# 2964   22    Male               Computer Science            1     7       0
# 2965   23    Male                          Civil            0     8       0
#
#       HistoryOfBacklogs  PlacedOrNot Habit
# ...

# %%
df.drop("Habit",axis=1)
# Out:
#       Age  Gender                         Stream  Internships  CGPA  Hostel  \
# 0      22    Male  Electronics And Communication            1     8       1
# 1      21  Female               Computer Science            0     7       1
# 2      22  Female         Information Technology            1     6       0
# 3      21    Male         Information Technology            0     8       0
# 4      22    Male                     Mechanical            0     8       1
# ...   ...     ...                            ...          ...   ...     ...
# 2961   23    Male         Information Technology            0     7       0
# 2962   23    Male                     Mechanical            1     7       1
# 2963   22    Male         Information Technology            1     7       0
# 2964   22    Male               Computer Science            1     7       0
# 2965   23    Male                          Civil            0     8       0
#
#       HistoryOfBacklogs  PlacedOrNot
# ...

# %%
df[df.Age.between(24,25)]
# Out:
#       Age  Gender                         Stream  Internships  CGPA  Hostel  \
# 103    24    Male         Information Technology            2     6       0
# 106    24  Female         Information Technology            0     6       0
# 107    24    Male         Information Technology            1     7       0
# 108    24    Male                          Civil            1     7       0
# 111    24    Male  Electronics And Communication            1     6       0
# ...   ...     ...                            ...          ...   ...     ...
# 1863   24    Male                     Mechanical            1     7       1
# 1868   24    Male               Computer Science            1     7       0
# 1872   24    Male                     Electrical            1     7       0
# 1886   24    Male  Electronics And Communication            0     6       0
# 1887   24    Male                          Civil            1     6       0
#
#       HistoryOfBacklogs  PlacedOrNot
# ...

# %%
df
# Out:
#       Age  Gender                         Stream  Internships  CGPA  Hostel  \
# 0      22    Male  Electronics And Communication            1     8       1
# 1      21  Female               Computer Science            0     7       1
# 2      22  Female         Information Technology            1     6       0
# 3      21    Male         Information Technology            0     8       0
# 4      22    Male                     Mechanical            0     8       1
# ...   ...     ...                            ...          ...   ...     ...
# 2961   23    Male         Information Technology            0     7       0
# 2962   23    Male                     Mechanical            1     7       1
# 2963   22    Male         Information Technology            1     7       0
# 2964   22    Male               Computer Science            1     7       0
# 2965   23    Male                          Civil            0     8       0
#
#       HistoryOfBacklogs  PlacedOrNot
# ...

# %%
df.Gender.value_counts()
# Out:
# Gender
# Male      2475
# Female     491
# Name: count, dtype: int64

# %%
df["Hostel"].hasnans
# Out:
# False
