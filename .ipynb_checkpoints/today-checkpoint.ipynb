# %% [markdown]
# ### find total number of male and female
# ### find total number of software engineers
# ### find total number of unique occupation
# ### find rtotal number of people are overweight
# ### find total number of people who are obese
# ### find total number of people whose heart rate is >= 60 and <= 80
# ### find total numebe of people whose activity level is greater than 30
# ### find the highest activity level and find how many people belong to that category
# ### make two columns systolic and diastiloc and fill it with values from blood pressure column
# ### find correlation between sysolic and diastolic blood pressure and heatrate
# ### find corr between quality of sleep, sleep duration and heart rate

# %%
import pandas as pd
# Out:
# /Users/umeshregmi/miniconda3/lib/python3.10/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
df = pd.read_csv('Sleep_health_and_lifestyle_dataset.csv')

# %%
df.head()
# Out:
#    Person ID Gender  Age            Occupation  Sleep Duration  \
# 0          1   Male   27     Software Engineer             6.1
# 1          2   Male   28                Doctor             6.2
# 2          3   Male   28                Doctor             6.2
# 3          4   Male   28  Sales Representative             5.9
# 4          5   Male   28  Sales Representative             5.9
#
#    Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                 6                       42             6   Overweight
# 1                 6                       60             8       Normal
# 2                 6                       60             8       Normal
# 3                 4                       30             8        Obese
# 4                 4                       30             8        Obese
#
#   Blood Pressure  Heart Rate  Daily Steps Sleep Disorder
# 0         126/83          77         4200            NaN
# ...

# %%
df.Gender.value_counts().loc['Male']
# Out:
# 189

# %%
(df.Gender == 'Male').sum()
# Out:
# 189

# %%
(df.Gender.str.lower() == 'male').sum()
# Out:
# 189

# %%
(df.Gender.str.lower() == 'female').sum()
# Out:
# 185

# %%
df.Occupation.unique()
# Out:
# array(['Software Engineer', 'Doctor', 'Sales Representative', 'Teacher',
#        'Nurse', 'Engineer', 'Accountant', 'Scientist', 'Lawyer',
#        'Salesperson', 'Manager'], dtype=object)

# %%
df.Occupation.value_counts().loc['Software Engineer']
# Out:
# 4

# %%
(df.Occupation == 'Software Engineer').sum()
# Out:
# 4

# %%
len(df.Occupation.unique())
# Out:
# 11

# %%
df.Occupation.nunique()
# Out:
# 11

# %%
df['BMI Category'].unique()
# Out:
# array(['Overweight', 'Normal', 'Obese', 'Normal Weight'], dtype=object)

# %%
(df['BMI Category'] == 'Overweight').sum()
# Out:
# 148

# %%
(df['BMI Category'] == 'Obese').sum()
# Out:
# 10

# %%
((df['Heart Rate'] >= 60) & (df['Heart Rate'] <= 80)).sum()
# Out:
# 362

# %%
df['Heart Rate'].between(60, 80).sum()
# Out:
# 362

# %%
(df['Physical Activity Level'] > 30).sum()
# Out:
# 306

# %%
df[df['Physical Activity Level'] > 30]
# Out:
#      Person ID  Gender  Age         Occupation  Sleep Duration  \
# 0            1    Male   27  Software Engineer             6.1
# 1            2    Male   28             Doctor             6.2
# 2            3    Male   28             Doctor             6.2
# 6            7    Male   29            Teacher             6.3
# 7            8    Male   29             Doctor             7.8
# ..         ...     ...  ...                ...             ...
# 369        370  Female   59              Nurse             8.1
# 370        371  Female   59              Nurse             8.0
# 371        372  Female   59              Nurse             8.1
# 372        373  Female   59              Nurse             8.1
# 373        374  Female   59              Nurse             8.1
#
#      Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                   6                       42             6   Overweight
# ...

# %%
df['Physical Activity Level'].max()
# Out:
# 90

# %%
df[df['Physical Activity Level'] == 90]
# Out:
#      Person ID  Gender  Age Occupation  Sleep Duration  Quality of Sleep  \
# 163        164    Male   40     Lawyer             7.9                 8
# 164        165    Male   40     Lawyer             7.9                 8
# 165        166    Male   41     Lawyer             7.6                 8
# 169        170    Male   41     Lawyer             7.7                 8
# 170        171    Male   41     Lawyer             7.7                 8
# ..         ...     ...  ...        ...             ...               ...
# 303        304  Female   51      Nurse             6.0                 6
# 304        305  Female   51      Nurse             6.1                 6
# 305        306  Female   51      Nurse             6.1                 6
# 341        342  Female   56     Doctor             8.2                 9
# 342        343  Female   56     Doctor             8.2                 9
#
#      Physical Activity Level  Stress Level   BMI Category Blood Pressure  \
# ...

# %%
(df['Physical Activity Level'] == 90).sum()
# Out:
# 67

# %%
df.head()
# Out:
#    Person ID Gender  Age            Occupation  Sleep Duration  \
# 0          1   Male   27     Software Engineer             6.1
# 1          2   Male   28                Doctor             6.2
# 2          3   Male   28                Doctor             6.2
# 3          4   Male   28  Sales Representative             5.9
# 4          5   Male   28  Sales Representative             5.9
#
#    Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                 6                       42             6   Overweight
# 1                 6                       60             8       Normal
# 2                 6                       60             8       Normal
# 3                 4                       30             8        Obese
# 4                 4                       30             8        Obese
#
#   Blood Pressure  Heart Rate  Daily Steps Sleep Disorder
# 0         126/83          77         4200            NaN
# ...

# %%
df['Systolic'] = df['Blood Pressure'].apply(lambda x: x.split('/')[0])

# %%
df['Diastolic'] = df['Blood Pressure'].apply(lambda x: x.split('/')[1])

# %%
df.drop('Blood Pressure', axis=1, inplace=True)

# %%
df
# Out:
#      Person ID  Gender  Age            Occupation  Sleep Duration  \
# 0            1    Male   27     Software Engineer             6.1
# 1            2    Male   28                Doctor             6.2
# 2            3    Male   28                Doctor             6.2
# 3            4    Male   28  Sales Representative             5.9
# 4            5    Male   28  Sales Representative             5.9
# ..         ...     ...  ...                   ...             ...
# 369        370  Female   59                 Nurse             8.1
# 370        371  Female   59                 Nurse             8.0
# 371        372  Female   59                 Nurse             8.1
# 372        373  Female   59                 Nurse             8.1
# 373        374  Female   59                 Nurse             8.1
#
#      Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                   6                       42             6   Overweight
# ...

# %%
corr_df = df[['Heart Rate', 'Systolic', 'Diastolic']]

# %%
corr_df.corr()
# Out:
#             Heart Rate  Systolic  Diastolic
# Heart Rate    1.000000  0.294143   0.271092
# Systolic      0.294143  1.000000   0.972885
# Diastolic     0.271092  0.972885   1.000000

# %%
temp_df = df[['Sleep Duration', 'Quality of Sleep', 'Heart Rate']]

# %%
temp_df.corr()
# Out:
#                   Sleep Duration  Quality of Sleep  Heart Rate
# Sleep Duration          1.000000          0.883213   -0.516455
# Quality of Sleep        0.883213          1.000000   -0.659865
# Heart Rate             -0.516455         -0.659865    1.000000
